# %% [markdown]
# # 단일 레이어로 학습시키기

# %% [markdown]
# ## 데이터 준비
# > 보스턴 집값 데이터 URL : "https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/boston.csv"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# pandas로 URL을 통해 데이터 가져오기

import pandas as pd

boston = pd.read_csv()

# %%
# 문제 : 샘플 개수?, 피쳐 개수?    즉, 행과 열의 개수는?

# %%
# 문제 : 전체 데이터 보기

# %%
# 처음 5개 확인

boston.head()

# %%
# 문제 : 마지막 5개 확인

# %%
# 원하는 특성만 자르기

# crim(범죄율) 피쳐만 자르기
boston['crim']

# %%
# 문제 : chas(찰스강 전망), rm(방개수) 피쳐만 자르기
boston[]

# %%
# 문제 :독립변수와 종속변수로 분리하기
# 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat', 'medv'
# 참고 : 모든 feature를 보고 싶을 때 boston.columns

X = boston[] # 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat'
Y = boston[] # 'medv'

# %%
# 독립변수, 종속변수 분리된 상태 확인

X

# %% [markdown]
# ## 모델 설계하기 및 학습 시키기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 케라스 모델 생성에 필요한 함수 가져오기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 모델 설계하기
model = Sequential()
model.add(Dense(?, input_dim=??))
model.compile(optimizer='sgd', loss='mse')   # 다른 최적화기로 변경해 보기 rmsprop

# 모델 학습시키기
model.fit(X, Y, epochs=20)

# %%
# 모델 요약보기
model.summary()

# 문제 : total 파라미터 개수?  왜?

# %% [markdown]
# ## 모델 활용하기

# %%
# 각 가중치(w1 ~ w13)와 편향(b) 확인해 보기

model.get_weights()

# %%
# 독립변수의 0번 ~ 4번까지의 데이터로 집값 예측해 보기
model.predict(X[0:5])

# %%
# 0번 ~ 4번까지 실제 가격 출력해 보기
Y[0:5]

# %% [markdown]
# # 멀티 레이어로 학습하기

# %% [markdown]
# ## 데이터 준비

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 데이터 준비하기
boston = pd.read_csv("https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/boston.csv")

X = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']] # 
Y = boston['medv'] # 'medv'

# %% [markdown]
# ## 모델 설계하기 및 학습 시키기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 모델 설계하기
model = Sequential()
model.add(Dense(??, input_dim=13))
model.add(Dense(?))          # 활성화 함수를 지정해 보자.
model.add(Dense(?))
model.compile(optimizer='rmsprop', loss='mse')

# 모델 학습 시키기
model.fit(X, Y, epochs=2000)

# %%
# 모델 요약보기
model.summary()

# 문제 : total 파라미터 개수?  왜?

# %% [markdown]
# ## 모델 활용하기

# %%
# 각 가중치(w1 ~ w13)와 편향(b) 확인해 보기

model.get_weights()

# %%
# 독립변수의 0번 ~ 4번까지의 데이터로 집값 예측해 보기
model.predict(X[0:5])

# %%
# 0번 ~ 4번까지의 실제 집값 예측해 보기
Y[0:5]
