# %% [markdown]
# # Stable Diffusion V2를 이미지 생성 모델 활용
# ## 내가 원하는 그림을 그려주는 AI 모델
# ## 그림으로 이해하는 Stable Diffusion (번역)
# https://velog.io/@hammerimpact/%EA%B7%B8%EB%A6%BC%EC%9C%BC%EB%A1%9C-%EC%9D%B4%ED%95%B4%ED%95%98%EB%8A%94-Stable-Diffusion-%EB%B2%88%EC%97%AD

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 런타임 -> 런타임 유형 변경 -> None를 GPU
# !nvidia-smi #사용하는 GPU를 보여줌.

# %% [markdown]
# ## stable diffusion v2 관련 모듈 및 모델 다운로드 참고 사이트
# https://huggingface.co/stabilityai/stable-diffusion-2

# %%
# stable diffusion 및 각종 연산을 위한 라이브러리(모듈) 설치

# %%
# 모델 다운로드 및 로딩

# %% [markdown]
# ### 예시 프롬프트
#    https://stablediffusionweb.com/prompts

# %% [markdown]
# # 구글 번역기로 한영 번역
#
# https://blockdmask.tistory.com/540

# %%
# 구글 번역 모듈 설치

# %% [markdown]
# ## 프롬프트를 한글로 입력하면 영어로 번역하여 이미지 생성
