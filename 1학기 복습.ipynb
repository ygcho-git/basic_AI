# %% [markdown]
# # 선형회귀(보스턴 집값 예측)

# %%
# 1. 모듈 불러오기
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 2. 데이터 준비하기
boston = pd.read_csv("https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/boston.csv")

boston

# %%
# 3. 입력데이터(독립변수), 출력데이터(종속변수) 분리하기
X = boston[]
Y = boston[]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4. 모델 설계하기

# %%
# 5. 모델 학습시키기
model.fit(X, Y, epochs=100)

# %%
# 6. 모델 요약 보기

# %%
# 독립변수의 0번 ~ 4번까지의 데이터로 집값 예측해 보기
model.predict(X[0:5])

# %%
# 0번 ~ 4번까지의 실제 집값 예측해 보기
Y[0:5]

# %% [markdown]
# # 이진분류 - 피마 인디언 당뇨병 예측 모델

# %% [markdown]
# ```
# # 컬럼 의미
# pregnancies: 임신 횟수
# plasma: 포도당 부하 검사 수치
# pressure: 혈압(mm Hg)
# thickness: 팔 삼두근 뒤쪽의 피하지방 측정값(mm)
# insulin: 혈청 인슐린(mu U/ml)
# bmi: 체질량지수(체중(kg)/키(m))^2
# pedigree: 당뇨 내력 가중치 값
# age: 나이
# diabetes: 당뇨병 유무 (0 또는 1)
# ```
# ![image.png](data:image/png;base64,...)

# %%
# 1. 모듈 불러오기
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 2. 데이터 준비하기
pima = pd.read_csv('https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/pima-indians-diabetes3.csv')

# %%
# 3. 입력데이터(독립변수), 출력데이터(종속변수) 분리하기
X =
Y =

# %% [markdown]
# ```
# 입력층
# 첫번째 히든레이어 12
# 두번째 히든레이어 18
# 세번째 히든레이어 8
# 출력층
# ```

# %%
# 4. 모델 설계하기
model = Sequential()
model.add( Dense(12, input_dim=, activation='?') )
model.add( Dense(16, activation='?') )
model.add( Dense(8, activation='?') )
model.add( Dense(1, activation='?') )

model.compile(optimizer='adam', loss='?', metrics=['accuracy'])

# %%
# 5. 모델 학습 시키

# %%
# 모델 예측
model.predict(X[:5])

# %%
# 실제 결과
Y[:5]

# %% [markdown]
# # 다중 분류 - 붓꽃 품종 분류

# %% [markdown]
# 꽃의 분류
# 꽃잎길이, 꽃잎폭, 꽃받침길이, 꽃받침폭 --> setosa, virsicolor, virginica
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. 모듈 불러오기
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 2. 데이터 불러오기
iris = pd.read_csv('https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/iris.csv')

# %%
# 3. 입력데이터(독립변수), 출력데이터(종속변수)로 나누기

X = iris[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
Y = iris['품종']

# %% [markdown]
# One-Hot Encoding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Y(종속) 값을 원핫인코딩
Y =

# %%
# 4. 모델 설계
model = Sequential()
model.add(Dense(10, input_dim=4, activation='?'))
model.add(Dense(16, activation='?'))
model.add(Dense(8, activation='?'))
model.add(Dense(?, activation='?'))

# 모델 설정
model.compile(optimizer='adam', loss='??', metrics='accuracy')

# %%
# 5. 모델 학습
model.fit(X, Y, epochs=10)

# %%
# 모델 예측하기
model.predict(X[:5])

# %%
Y[:5]
