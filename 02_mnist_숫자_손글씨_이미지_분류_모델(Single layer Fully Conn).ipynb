# %% [markdown]
# # mnist 단층 레이어(Single-Layer)로 이미지 분류 모델 개발

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 필요한 모듈 불러오기
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
import pandas as pd

# %%
# 데이터 다운받기
(train_x, train_y), (test_x, test_y) = mnist.load_data()
print(train_x.shape, train_y.shape)

# %%
# 데이터 전처리
train_x =        # (60000, 28, 28) --> (60000, 784) 로 변환
train_y =        # one-hot 인코딩

print(train_x.shape)
print(train_y.shape)

# %%
# 모델 설계
model = Sequential()

# %%
# train_x 데이터로 예측해 보자.(보기좋게 출력되도록 해보기...)
model.predict(train_x[0:5])

#df_pred = pd.DataFrame(pred)   # round()메소드
#df_pred

# %%
# train_x[0] 을 숫자로 볼까?

# %%
# train_x[0] 을 그림으로 볼까?

# %%
# 정답을 출력해 보자...
train_y[0:5]

# %%
# test_x 데이터를 예측해 보기 0 ~ 10번 자료로
model.predict(?????)


#df_pred = pd.DataFrame(pred)   # round()메소드
#df_pred

# %%
test_y[0:10]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 모델 요약보기
model.summary()

# %%
# 가중치와 편향을 보기
model.get_weights()

# %%
# 편향값만 분리해 보자.

# %%
# 가중치만 분리해 보자

# %%
# 가중치를 판다스 데이터 프레임으로 예쁘게 보자.

# %%
# 가중치에서 0에 대한 가중치만 보기, 반올림

# %%
# 0에 대한 가중치를 28 x 28로 보기

# %%
# 0에 대한 가중치를 28 x 28의 이미지로 보자

# %%
# 전체코드

# 필요한 모듈 불러오기
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
import pandas as pd

# 데이터 다운받기
(train_x, train_y), (test_x, test_y) = mnist.load_data()

# 데이터 전처리
train_x = train_x.reshape(60000, 784)   # (60000, 28, 28) --> (60000, 784) 로 변환
train_y = pd.get_dummies(train_y)       # one-hot 인코딩

# 모델 설계
model = Sequential()
model.add(Input(shape=(784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(train_x, train_y, epochs=10)
